# %% [markdown]
# ### Singly Linked List

# %% [markdown]
# 1) Insertion at the begining of the SLL

# %%
class Node:
    def __init__(self,data=None,next=None):
        self.data = data
        self.next = next
        
class LinkedList:
    def __init__(self):
        self.head = None
        
    def insert_at_begining(self,data):
        node = Node(data, self.head)
        self.head = node
        
    def print(self):
        if self.head is None:
            print("Linked list is empty")
            return
        
        #Traversal trough the linked list
        itr = self.head          #iterator
                               #itr is a pointer to the first(head) node
        llstr = ''             #string to store the linked list representation
                               #we will traverse the linked list and append each node's data to llstr
        while itr:              #while itr is not None:
            llstr +=str(itr.data) + '-->'  #append the data of the current node
                                     
            itr = itr.next           #move to the next node
            
        print(llstr)                 #print the linked list representation
        
if __name__ == '__main__':
    ll = LinkedList()
    ll.insert_at_begining(5)
    ll.insert_at_begining(89)
    ll.print()
# Out:
# 89-->5-->

# %% [markdown]
# ✅ Explanation:
# itr = self.head
# You create a variable itr (short for “iterator”).
#
# You set it to point to the first node of the linked list (self.head).
#
# This is so you can walk through the list without changing the actual head pointer.
#
# llstr = ''
# You create an empty string llstr.
#
# This will be used to build a textual representation of your linked list (for printing).
#
# while itr:
# This loop runs as long as itr is not None.
#
# In each iteration, itr points to the current node you’re visiting.
#
# llstr += str(itr.data) + '-->'
# You take the data value stored in the current node.
#
# Convert it to a string with str(itr.data).
#
# Add '-->' after it.
#
# Append this to the llstr string.
#
# This builds a string like:
#
# rust
# Copy code
# 89-->5-->
# for a linked list with nodes containing 89 and 5.

# %% [markdown]
# 2) Insertion at the end of the SLL

# %%
class Node:
    def __init__(self,data=None,next=None):
        self.data = data
        self.next = next
        
class LinkedList:
    def __init__(self):
        self.head = None
        
    def insert_at_begining(self,data):
        node = Node(data, self.head)
        self.head = node
        
    def print(self):
        if self.head is None:
            print("Linked list is empty")
            return
        
        itr = self.head
        llstr = ''
        while itr:
            llstr +=str(itr.data) + '-->'
            itr = itr.next
            
        print(llstr)
        
    def insert_at_end(self,data):
        if self.head is None:
            self.head = Node(data,None) #Because last node will point to None and we need to create
            #a new node beacause the list is empty
            return
        
        itr = self.head
        while itr.next:        #while itr.next is not None:
            itr = itr.next
            
        itr.next = Node(data,None)
        
if __name__ == '__main__':
    ll = LinkedList()
    ll.insert_at_begining(5)
    ll.insert_at_begining(89)
    ll.insert_at_end(100)
    ll.print()
# Out:
# 89-->5-->100-->

# %% [markdown]
# 3. Taking a list of data as input and from them directly creating a SLL

# %%
class Node:
    def __init__(self,data=None,next=None):
        self.data = data
        self.next = next
        
class LinkedList:
    def __init__(self):
        self.head = None
        
   
    def print(self):
        if self.head is None:
            print("Linked list is empty")
            return
        
        itr = self.head
        llstr = ''
        while itr:
            llstr +=str(itr.data) + '-->'
            itr = itr.next
            
        print(llstr)
        
    def insert_at_end(self,data):
        if self.head is None:
            self.head = Node(data,None) #Because last node will point to None and we need to create
            #a new node beacause the list is empty
            return
        
        itr = self.head
        while itr.next:        #while itr.next is not None:
            itr = itr.next
            
        itr.next = Node(data,None)
        
        
        
    def insert_values(self, data_list):
        self.head = None
        for data in data_list:
            self.insert_at_end(data)
        
if __name__ == '__main__':
    ll = LinkedList()
    ll.insert_values([5, 89, 100, 200])
    ll.print()
# Out:
# 5-->89-->100-->200-->

# %% [markdown]
# 4) To get a length of the LL

# %%
class Node:
    def __init__(self,data=None,next=None):
        self.data = data
        self.next = next
        
class LinkedList:
    def __init__(self):
        self.head = None
        
   
    def print(self):
        if self.head is None:
            print("Linked list is empty")
            return
        
        itr = self.head
        llstr = ''
        while itr:
            llstr +=str(itr.data) + '-->'
            itr = itr.next
            
        print(llstr)
        
    def insert_at_end(self,data):
        if self.head is None:
            self.head = Node(data,None) #Because last node will point to None and we need to create
            #a new node beacause the list is empty
            return
        
        itr = self.head
        while itr.next:        #while itr.next is not None:
            itr = itr.next
            
        itr.next = Node(data,None)
        
        
        
    def insert_values(self, data_list):
        self.head = None
        for data in data_list:
            self.insert_at_end(data)
            
            
    def get_length(self):
        count = 0
        itr = self.head
        while itr:
            count+=1
            itr = itr.next
        return count
        
if __name__ == '__main__':
    ll = LinkedList()
    ll.insert_values([5, 89, 100, 200])
    ll.print()
    print("Length:",ll.get_length())
# Out:
# 5-->89-->100-->200-->
# Length: 4

# %% [markdown]
# 5. Remove the element at a perticular position.

# %%
class Node:
    def __init__(self,data=None,next=None):
        self.data = data
        self.next = next
        
class LinkedList:
    def __init__(self):
        self.head = None
        
   
    def print(self):
        if self.head is None:
            print("Linked list is empty")
            return
        
        itr = self.head
        llstr = ''
        while itr:
            llstr +=str(itr.data) + '-->'
            itr = itr.next
            
        print(llstr)
        
    def insert_at_end(self,data):
        if self.head is None:
            self.head = Node(data,None) #Because last node will point to None and we need to create
            #a new node beacause the list is empty
            return
        
        itr = self.head
        while itr.next:        #while itr.next is not None:
            itr = itr.next
            
        itr.next = Node(data,None)
        
        
        
    def insert_values(self, data_list):
        self.head = None
        for data in data_list:
            self.insert_at_end(data)
            
            
    def get_length(self):
        count = 0
        itr = self.head
        while itr:
            count+=1
            itr = itr.next
        return count
        
        
        
    def remove_at(self, index):
        if index < 0 or index>=self.get_length():
            raise Exception("Invalid index")
        if index == 0:
            self.head = self.head.next
            return
        
        count = 0
        itr = self.head
        while itr:
            if count == index-1:
                itr.next = itr.next.next
                break
            itr = itr.next
            count +=1
            
if __name__ == '__main__':
    ll = LinkedList()
    ll.insert_values([5, 89, 100, 200])
    ll.print()
    ll.remove_at(2)
    #ll.remove_at(-1)
    ll.remove_at(20)
    ll.print()
# Out:
# 5-->89-->100-->200-->
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[11], line 76
#      74 ll.remove_at(2)
#      75 #ll.remove_at(-1)
# ---> 76 ll.remove_at(20)
#      77 ll.print()
#
# Cell In[11], line 56, in LinkedList.remove_at(self, index)
#      54 def remove_at(self, index):
#      55     if index < 0 or index>=self.get_length():
# ---> 56         raise Exception("Invalid index")
#      57     if index == 0:
#      58         self.head = self.head.next
#
# Exception: Invalid index

# %% [markdown]
# 6.Insert at a perticular position

# %%
class Node:
    def __init__(self,data=None,next=None):
        self.data = data
        self.next = next
        
class LinkedList:
    def __init__(self):
        self.head = None
        
   
    def print(self):
        if self.head is None:
            print("Linked list is empty")
            return
        
        itr = self.head
        llstr = ''
        while itr:
            llstr +=str(itr.data) + '-->'
            itr = itr.next
            
        print(llstr)
        
    def insert_at_end(self,data):
        if self.head is None:
            self.head = Node(data,None) #Because last node will point to None and we need to create
            #a new node beacause the list is empty
            return
        
        itr = self.head
        while itr.next:        #while itr.next is not None:
            itr = itr.next
            
        itr.next = Node(data,None)
        
        
        
    def insert_values(self, data_list):
        self.head = None
        for data in data_list:
            self.insert_at_end(data)
            
    def get_length(self):
        count = 0
        itr = self.head
        while itr:
            count+=1
            itr = itr.next
        return count
            
    def insert_at(self, index, data):
        if index<0 or index>self.get_length():
            raise Exception("Invalid Index")
        
        if index==0:
            self.insert_at_begining(data)
            return 
        
        count =0
        itr = self.head
        while itr:
            if count == index-1:
                node=Node(data,itr.next)
                itr.next = node
                break
            itr = itr.next
            count +=1       
    
        
        
            
if __name__ == '__main__':
    ll = LinkedList()
    ll.insert_values(["banana","mango","grapes","orange"])
    ll.print()
    ll.insert_at(2,"kiwi")
    ll.print()
    ll.insert_at(3,"apple")
    ll.print()
# Out:
# banana-->mango-->grapes-->orange-->
# banana-->mango-->kiwi-->grapes-->orange-->
# banana-->mango-->kiwi-->apple-->grapes-->orange-->

# %% [markdown]
# Source code of the tutorial

# %%
class Node:
    def __init__(self, data=None, next=None):
        self.data = data
        self.next = next

class LinkedList:
    def __init__(self):
        self.head = None

    def print(self):
        if self.head is None:
            print("Linked list is empty")
            return
        itr = self.head
        llstr = ''
        while itr:
            llstr += str(itr.data)+' --> ' if itr.next else str(itr.data)
            itr = itr.next
        print(llstr)

    def get_length(self):
        count = 0
        itr = self.head
        while itr:
            count+=1
            itr = itr.next

        return count

    def insert_at_begining(self, data):
        node = Node(data, self.head)
        self.head = node

    def insert_at_end(self, data):
        if self.head is None:
            self.head = Node(data, None)
            return

        itr = self.head

        while itr.next:
            itr = itr.next

        itr.next = Node(data, None)

    def insert_at(self, index, data):
        if index<0 or index>self.get_length():
            raise Exception("Invalid Index")

        if index==0:
            self.insert_at_begining(data)
            return

        count = 0
        itr = self.head
        while itr:
            if count == index - 1:
                node = Node(data, itr.next)
                itr.next = node
                break

            itr = itr.next
            count += 1

    def remove_at(self, index):
        if index<0 or index>=self.get_length():
            raise Exception("Invalid Index")

        if index==0:
            self.head = self.head.next
            return

        count = 0
        itr = self.head
        while itr:
            if count == index - 1:
                itr.next = itr.next.next
                break

            itr = itr.next
            count+=1

    def insert_values(self, data_list):
        self.head = None
        for data in data_list:
            self.insert_at_end(data)


if __name__ == '__main__':
    ll = LinkedList()
    ll.insert_values(["banana","mango","grapes","orange"])
    ll.insert_at(1,"blueberry")
    ll.remove_at(2)
    ll.print()

    ll.insert_values([45,7,12,567,99])
    ll.insert_at_end(67)
    ll.print()
# Out:
# banana --> blueberry --> grapes --> orange
# 45 --> 7 --> 12 --> 567 --> 99 --> 67

# %% [markdown]
# 7. Remove element of a perticular position

# %%
class Node:
    def __init__(self,data=None,next=None):
        self.data = data
        self.next = next
        
class LinkedList:
    def __init__(self):
        self.head = None
        
   
    def print(self):
        if self.head is None:
            print("Linked list is empty")
            return
        
        itr = self.head
        llstr = ''
        while itr:
            llstr +=str(itr.data) + '-->'
            itr = itr.next
            
        print(llstr)
        
    def insert_at_end(self,data):
        if self.head is None:
            self.head = Node(data,None) #Because last node will point to None and we need to create
            #a new node beacause the list is empty
            return
        
        itr = self.head
        while itr.next:        #while itr.next is not None:
            itr = itr.next
            
        itr.next = Node(data,None)
        
        
        
    def insert_values(self, data_list):
        self.head = None
        for data in data_list:
            self.insert_at_end(data)
            
    def get_length(self):
        count = 0
        itr = self.head
        while itr:
            count+=1
            itr = itr.next
        return count
            
    def insert_at(self, index, data):
        if index<0 or index>self.get_length():
            raise Exception("Invalid Index")
        
        if index==0:
            self.insert_at_begining(data)
            return 
        
        count =0
        itr = self.head
        while itr:
            if count == index-1:
                node=Node(data,itr.next)
                itr.next = node
                break
            itr = itr.next
            count +=1  
     
            
    def remove_by_value(self, data):
        if self.head is None:
            return

        if self.head.data == data:
            self.head = self.head.next
            return

        itr = self.head
        while itr.next:
            if itr.next.data == data:
                itr.next = itr.next.next
                break
            itr = itr.next
     
    
        
        
            
if __name__ == '__main__':
    ll = LinkedList()
    ll.insert_values(["banana","mango","grapes","orange"])
    ll.print()
    ll.remove_by_value("grapes")
    ll.print()
    ll.remove_by_value("figs")
    ll.print()
# Out:
# banana-->mango-->grapes-->orange-->
# banana-->mango-->orange-->
# banana-->mango-->orange-->

# %% [markdown]
# ###### Before:   itr → node_with_data → next_node
# ###### After:    itr → next_node

# %% [markdown]
# 8. Insert after value

# %%
class Node:
    def __init__(self,data=None,next=None):
        self.data = data
        self.next = next
        
class LinkedList:
    def __init__(self):
        self.head = None
        
   
    def print(self):
        if self.head is None:
            print("Linked list is empty")
            return
        
        itr = self.head
        llstr = ''
        while itr:
            llstr +=str(itr.data) + '-->'
            itr = itr.next
            
        print(llstr)
        
    def insert_at_end(self,data):
        if self.head is None:
            self.head = Node(data,None) #Because last node will point to None and we need to create
            #a new node beacause the list is empty
            return
        
        itr = self.head
        while itr.next:        #while itr.next is not None:
            itr = itr.next
            
        itr.next = Node(data,None)
        
        
        
    def insert_values(self, data_list):
        self.head = None
        for data in data_list:
            self.insert_at_end(data)
            
    def get_length(self):
        count = 0
        itr = self.head
        while itr:
            count+=1
            itr = itr.next
        return count
            
    def insert_at(self, index, data):
        if index<0 or index>self.get_length():
            raise Exception("Invalid Index")
        
        if index==0:
            self.insert_at_begining(data)
            return 
        
        count =0
        itr = self.head
        while itr:
            if count == index-1:
                node=Node(data,itr.next)
                itr.next = node
                break
            itr = itr.next
            count +=1
            
            
    def insert_after_value(self, data_after, data_to_insert):
        if self.head is None:
            return

        if self.head.data==data_after:
            self.head.next = Node(data_to_insert,self.head.next)
            return

        itr = self.head
        while itr:
            if itr.data == data_after:
                itr.next = Node(data_to_insert, itr.next)
                break

            itr = itr.next  
     
            
                
if __name__ == '__main__':
    ll = LinkedList()
    ll.insert_values(["banana","mango","grapes","orange"])
    ll.print()
    ll.insert_after_value("mango","apple")
    ll.print()
# Out:
# banana-->mango-->grapes-->orange-->
# banana-->mango-->apple-->grapes-->orange-->
